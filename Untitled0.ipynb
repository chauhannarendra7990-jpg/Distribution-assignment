# %%
Statistics Assignment - Answer Sheet
1. Simulate 30 rolls with =RANDBETWEEN(1,6). What is the probability of rolling a 3 exactly 5 times?
• This is a binomial probability problem where:
  - Number of trials (n) = 30
  - Number of successes (k) = 5
  - Probability of success (p) = 1/6 (since a die has 6 faces)
• Formula:
  P(X = k) = C(n, k) * p^k * (1 - p)^(n - k)
• Using Excel:
  =BINOM.DIST(5, 30, 1/6, FALSE)
• Conclusion: This function returns the exact probability of getting exactly five 3s in 30 rolls.
2. Generate 100 values in Excel using the continuous uniform distribution RAND() and plot a histogram. Describe the shape of the distribution.
• The RAND() function generates values uniformly between 0 and 1.
• When plotted as a histogram, the bars are approximately equal in height.
• Conclusion: The shape of the distribution is flat and rectangular, indicating a uniform distribution.
3. A dataset has a mean of 50 and a standard deviation of 5. What percentage of values lie between 45 and 55 if the data follows a normal distribution?
• Given:
  - Mean (μ) = 50
  - Standard Deviation (σ) = 5
  - Range: 45 to 55 → This is μ ± 1σ
• Convert to Z-scores:
  Z1 = (45 - 50) / 5 = -1
  Z2 = (55 - 50) / 5 = +1
• From Z-table:
  P(Z ≤ 1) = 0.8413
  P(Z ≤ -1) = 0.1587
• Probability between Z = -1 and Z = +1:
  = 0.8413 - 0.1587 = 0.6826
• Conclusion: Approximately 68.26% of values lie between 45 and 55.
4. What is the concept of standardization (z-score), and why is it important in data analysis?
• Z-score formula:
  Z = (X - μ) / σ
• It represents how many standard deviations a value is from the mean.
• Importance:
  - Allows comparison across different datasets.
  - Helps detect outliers.
  - Converts data to a standard scale (mean = 0, SD = 1).
• Conclusion: Standardization is essential for normalization and comparative analysis.
5. What is Kurtosis and their type?
• Kurtosis measures the 'tailedness' and peak of a distribution.
• Types:
  - Mesokurtic: Normal peak and tails (e.g., normal distribution)
  - Leptokurtic: Sharp peak, heavy tails (more outliers)
  - Platykurtic: Flat peak, light tails (fewer outliers)
• Conclusion: Kurtosis helps understand the shape and extremity of data distribution.
6. Explain why the uniform distribution is a good model for the outcome of
